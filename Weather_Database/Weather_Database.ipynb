# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | la ronge
# Processing Record 2 of Set 1 | hammerfest
# Processing Record 3 of Set 1 | kruisfontein
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | lancaster
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | tilichiki
# Processing Record 8 of Set 1 | ugoofaaru
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | dingle
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | ulladulla
# Processing Record 18 of Set 1 | rabaul
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | pangnirtung
# Processing Record 21 of Set 1 | mackenzie
# Processing Record 22 of Set 1 | iquique
# Processing Record 23 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | luganville
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | cotonou
# Processing Record 30 of Set 1 | san policarpo
# Processing Record 31 of Set 1 | shakawe
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | lorengau
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | vardo
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | bambanglipuro
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | sechura
# Processing Record 45 of Set 1 | tabou
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | uruzgan
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | batticaloa
# Processing Record 50 of Set 1 | sutton
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | aripuana
# Processing Record 3 of Set 2 | ossora
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | koforidua
# Processing Record 9 of Set 2 | flinders
# Processing Record 10 of Set 2 | ciras
# City not found. Skipping...
# Processing Record 11 of Set 2 | terrak
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | encruzilhada do sul
# Processing Record 14 of Set 2 | odweyne
# Processing Record 15 of Set 2 | lipin bor
# Processing Record 16 of Set 2 | saint-joseph
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 2 | srandakan
# Processing Record 21 of Set 2 | hay river
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | cap malheureux
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | boende
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | pangkalanbuun
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | ostrovnoy
# Processing Record 37 of Set 2 | taoudenni
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | longyearbyen
# Processing Record 40 of Set 2 | emirdag
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | inirida
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | eyrarbakki
# Processing Record 46 of Set 2 | rafai
# Processing Record 47 of Set 2 | ayni
# Processing Record 48 of Set 2 | ketchikan
# Processing Record 49 of Set 2 | san jose
# Processing Record 50 of Set 2 | puerto narino
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | port-gentil
# Processing Record 3 of Set 3 | macklin
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | villavicencio
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | valdivia
# Processing Record 8 of Set 3 | caramay
# Processing Record 9 of Set 3 | standerton
# Processing Record 10 of Set 3 | russas
# Processing Record 11 of Set 3 | saldanha
# Processing Record 12 of Set 3 | san cristobal
# Processing Record 13 of Set 3 | ballina
# Processing Record 14 of Set 3 | nanakuli
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | patarlagele
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | ginir
# Processing Record 19 of Set 3 | omsukchan
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | sinnamary
# Processing Record 23 of Set 3 | kantunilkin
# Processing Record 24 of Set 3 | sao joao da barra
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | teguldet
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | pangoa
# Processing Record 33 of Set 3 | zhigansk
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | kirakira
# Processing Record 36 of Set 3 | los llanos de aridane
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | alvorada
# Processing Record 39 of Set 3 | berlevag
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | itupiranga
# Processing Record 43 of Set 3 | bayburt
# Processing Record 44 of Set 3 | abu kamal
# Processing Record 45 of Set 3 | whitehorse
# Processing Record 46 of Set 3 | cururupu
# Processing Record 47 of Set 3 | heihe
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | portland
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | yulara
# Processing Record 2 of Set 4 | kieta
# Processing Record 3 of Set 4 | masyaf
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | sarandi
# Processing Record 6 of Set 4 | namatanai
# Processing Record 7 of Set 4 | puerto penasco
# Processing Record 8 of Set 4 | mayo
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | bowen
# Processing Record 11 of Set 4 | karratha
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | padang
# Processing Record 16 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | nargana
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | humberto de campos
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | quetigny
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | vestmannaeyjar
# Processing Record 25 of Set 4 | teya
# Processing Record 26 of Set 4 | celle
# Processing Record 27 of Set 4 | pilar
# Processing Record 28 of Set 4 | cache creek
# Processing Record 29 of Set 4 | mezen
# Processing Record 30 of Set 4 | santa cruz
# Processing Record 31 of Set 4 | shetpe
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | saint andrews
# Processing Record 36 of Set 4 | silyanah
# City not found. Skipping...
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | anloga
# Processing Record 39 of Set 4 | puerto carreno
# Processing Record 40 of Set 4 | lagoa
# Processing Record 41 of Set 4 | burns lake
# Processing Record 42 of Set 4 | kenai
# Processing Record 43 of Set 4 | kuryk
# Processing Record 44 of Set 4 | codrington
# Processing Record 45 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | svetlogorsk
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 4 | ponta do sol
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | high level
# Processing Record 3 of Set 5 | yellowknife
# Processing Record 4 of Set 5 | saint-francois
# Processing Record 5 of Set 5 | mandurah
# Processing Record 6 of Set 5 | rodrigues alves
# Processing Record 7 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 8 of Set 5 | west bay
# Processing Record 9 of Set 5 | yeppoon
# Processing Record 10 of Set 5 | chapais
# Processing Record 11 of Set 5 | arraial do cabo
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | aklavik
# Processing Record 14 of Set 5 | galle
# Processing Record 15 of Set 5 | kuvandyk
# Processing Record 16 of Set 5 | kloulklubed
# Processing Record 17 of Set 5 | cockburn town
# Processing Record 18 of Set 5 | bo phloi
# Processing Record 19 of Set 5 | stamsund
# City not found. Skipping...
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | kromy
# Processing Record 22 of Set 5 | turayf
# Processing Record 23 of Set 5 | marsh harbour
# Processing Record 24 of Set 5 | sola
# Processing Record 25 of Set 5 | javanrud
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | chota
# Processing Record 28 of Set 5 | ndjole
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | alugan
# Processing Record 33 of Set 5 | nan
# Processing Record 34 of Set 5 | tupik
# Processing Record 35 of Set 5 | casper
# Processing Record 36 of Set 5 | alakurtti
# Processing Record 37 of Set 5 | alyangula
# Processing Record 38 of Set 5 | palana
# Processing Record 39 of Set 5 | baherden
# Processing Record 40 of Set 5 | japura
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | mafinga
# Processing Record 43 of Set 5 | ghogha
# Processing Record 44 of Set 5 | vao
# Processing Record 45 of Set 5 | kamenka
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | nemuro
# Processing Record 48 of Set 5 | salaga
# Processing Record 49 of Set 5 | glasgow
# Processing Record 50 of Set 5 | nova venecia
# Processing Record 1 of Set 6 | kiama
# Processing Record 2 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 6 | yumen
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | severo-kurilsk
# Processing Record 6 of Set 6 | fort nelson
# Processing Record 7 of Set 6 | bend
# Processing Record 8 of Set 6 | trabzon
# Processing Record 9 of Set 6 | batagay-alyta
# Processing Record 10 of Set 6 | sheridan
# Processing Record 11 of Set 6 | sao domingos
# Processing Record 12 of Set 6 | sulmona
# Processing Record 13 of Set 6 | beringovskiy
# Processing Record 14 of Set 6 | maceio
# Processing Record 15 of Set 6 | maniitsoq
# Processing Record 16 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 6 | borovskoy
# Processing Record 18 of Set 6 | madimba
# Processing Record 19 of Set 6 | porto novo
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | miles city
# Processing Record 22 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 23 of Set 6 | zhenhai
# Processing Record 24 of Set 6 | mackay
# Processing Record 25 of Set 6 | mushie
# Processing Record 26 of Set 6 | broken hill
# Processing Record 27 of Set 6 | nacala
# Processing Record 28 of Set 6 | poronaysk
# Processing Record 29 of Set 6 | ada
# Processing Record 30 of Set 6 | ivaipora
# Processing Record 31 of Set 6 | mukhen
# Processing Record 32 of Set 6 | buala
# Processing Record 33 of Set 6 | lata
# Processing Record 34 of Set 6 | dunedin
# Processing Record 35 of Set 6 | strelka
# Processing Record 36 of Set 6 | yagodnoye
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | edirne
# Processing Record 39 of Set 6 | udankudi
# Processing Record 40 of Set 6 | lompoc
# Processing Record 41 of Set 6 | quito
# Processing Record 42 of Set 6 | dudinka
# Processing Record 43 of Set 6 | anadyr
# Processing Record 44 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 6 | san luis
# Processing Record 46 of Set 6 | otautau
# Processing Record 47 of Set 6 | owando
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | tanabi
# Processing Record 50 of Set 6 | tonk
# Processing Record 1 of Set 7 | khuzhir
# Processing Record 2 of Set 7 | havre-saint-pierre
# Processing Record 3 of Set 7 | victoria
# Processing Record 4 of Set 7 | clyde river
# Processing Record 5 of Set 7 | belaya gora
# Processing Record 6 of Set 7 | upernavik
# Processing Record 7 of Set 7 | demirci
# Processing Record 8 of Set 7 | suao
# City not found. Skipping...
# Processing Record 9 of Set 7 | broome
# Processing Record 10 of Set 7 | nikolskoye
# Processing Record 11 of Set 7 | mangrol
# Processing Record 12 of Set 7 | hithadhoo
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | whitehaven
# Processing Record 15 of Set 7 | tambovka
# Processing Record 16 of Set 7 | bondoukou
# Processing Record 17 of Set 7 | mayor pablo lagerenza
# Processing Record 18 of Set 7 | gushikawa
# Processing Record 19 of Set 7 | vila velha
# Processing Record 20 of Set 7 | kualakapuas
# Processing Record 21 of Set 7 | ponta delgada
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 7 | tripoli
# Processing Record 25 of Set 7 | mahon
# Processing Record 26 of Set 7 | verkhnyaya khava
# Processing Record 27 of Set 7 | acapulco
# Processing Record 28 of Set 7 | deputatskiy
# Processing Record 29 of Set 7 | khurba
# Processing Record 30 of Set 7 | awjilah
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | alenquer
# Processing Record 33 of Set 7 | chicama
# Processing Record 34 of Set 7 | komsomolets
# Processing Record 35 of Set 7 | auki
# Processing Record 36 of Set 7 | simao
# Processing Record 37 of Set 7 | nenjiang
# Processing Record 38 of Set 7 | tautira
# Processing Record 39 of Set 7 | simoes
# Processing Record 40 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | tessalit
# Processing Record 43 of Set 7 | bereda
# Processing Record 44 of Set 7 | galesong
# Processing Record 45 of Set 7 | batagay
# Processing Record 46 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | hervey bay
# Processing Record 49 of Set 7 | edd
# Processing Record 50 of Set 7 | karachi
# Processing Record 1 of Set 8 | arteche
# Processing Record 2 of Set 8 | tocache
# Processing Record 3 of Set 8 | ewa beach
# Processing Record 4 of Set 8 | makaryev
# Processing Record 5 of Set 8 | christchurch
# Processing Record 6 of Set 8 | palmer
# Processing Record 7 of Set 8 | korla
# Processing Record 8 of Set 8 | touros
# Processing Record 9 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 8 | bac lieu
# Processing Record 12 of Set 8 | mnogovershinnyy
# Processing Record 13 of Set 8 | saint-augustin
# Processing Record 14 of Set 8 | ilo
# Processing Record 15 of Set 8 | da nang
# Processing Record 16 of Set 8 | amahai
# Processing Record 17 of Set 8 | show low
# Processing Record 18 of Set 8 | surt
# Processing Record 19 of Set 8 | tibagi
# Processing Record 20 of Set 8 | wetaskiwin
# Processing Record 21 of Set 8 | saint-georges
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | muroto
# Processing Record 24 of Set 8 | punta alta
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | tra vinh
# Processing Record 28 of Set 8 | braslav
# City not found. Skipping...
# Processing Record 29 of Set 8 | maneromango
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | bourail
# Processing Record 32 of Set 8 | wonosobo
# Processing Record 33 of Set 8 | mareeba
# Processing Record 34 of Set 8 | itarema
# Processing Record 35 of Set 8 | airai
# Processing Record 36 of Set 8 | koungou
# Processing Record 37 of Set 8 | ghanzi
# Processing Record 38 of Set 8 | igarka
# Processing Record 39 of Set 8 | pascagoula
# Processing Record 40 of Set 8 | kununurra
# Processing Record 41 of Set 8 | nara
# Processing Record 42 of Set 8 | bubaque
# Processing Record 43 of Set 8 | choya
# Processing Record 44 of Set 8 | itamarandiba
# Processing Record 45 of Set 8 | sibenik
# Processing Record 46 of Set 8 | coshocton
# Processing Record 47 of Set 8 | rab
# City not found. Skipping...
# Processing Record 48 of Set 8 | mandan
# Processing Record 49 of Set 8 | ocampo
# Processing Record 50 of Set 8 | miraflores
# Processing Record 1 of Set 9 | samarai
# Processing Record 2 of Set 9 | klecevce
# City not found. Skipping...
# Processing Record 3 of Set 9 | nhulunbuy
# Processing Record 4 of Set 9 | cortez
# Processing Record 5 of Set 9 | dicabisagan
# Processing Record 6 of Set 9 | les cayes
# Processing Record 7 of Set 9 | seoul
# Processing Record 8 of Set 9 | husavik
# Processing Record 9 of Set 9 | douglas
# Processing Record 10 of Set 9 | sadat
# Processing Record 11 of Set 9 | sitia
# Processing Record 12 of Set 9 | salamanca
# Processing Record 13 of Set 9 | tiznit
# Processing Record 14 of Set 9 | elat
# Processing Record 15 of Set 9 | sindi
# Processing Record 16 of Set 9 | zaozhuang
# Processing Record 17 of Set 9 | villanueva
# Processing Record 18 of Set 9 | ust-omchug
# Processing Record 19 of Set 9 | zhangye
# Processing Record 20 of Set 9 | tunxi
# City not found. Skipping...
# Processing Record 21 of Set 9 | arlit
# Processing Record 22 of Set 9 | ixtapa
# Processing Record 23 of Set 9 | muyezerskiy
# Processing Record 24 of Set 9 | rawson
# Processing Record 25 of Set 9 | la rioja
# Processing Record 26 of Set 9 | bagnols-sur-ceze
# Processing Record 27 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 9 | oyama
# Processing Record 29 of Set 9 | resistencia
# Processing Record 30 of Set 9 | mookane
# Processing Record 31 of Set 9 | teguise
# Processing Record 32 of Set 9 | omboue
# Processing Record 33 of Set 9 | hvide sande
# Processing Record 34 of Set 9 | naze
# Processing Record 35 of Set 9 | port blair
# Processing Record 36 of Set 9 | sitka
# Processing Record 37 of Set 9 | scarborough
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | sarangani
# Processing Record 41 of Set 9 | awbari
# Processing Record 42 of Set 9 | joshimath
# Processing Record 43 of Set 9 | eqbaliyeh
# Processing Record 44 of Set 9 | rorvik
# Processing Record 45 of Set 9 | shalya
# Processing Record 46 of Set 9 | wahiawa
# Processing Record 47 of Set 9 | nea kallikratia
# Processing Record 48 of Set 9 | morondava
# Processing Record 49 of Set 9 | maromitsa
# Processing Record 50 of Set 9 | najran
# Processing Record 1 of Set 10 | ahuimanu
# Processing Record 2 of Set 10 | burica
# City not found. Skipping...
# Processing Record 3 of Set 10 | qui nhon
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | elliot lake
# Processing Record 6 of Set 10 | urengoy
# Processing Record 7 of Set 10 | le moule
# Processing Record 8 of Set 10 | ahipara
# Processing Record 9 of Set 10 | oranjemund
# Processing Record 10 of Set 10 | wawa
# Processing Record 11 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 10 | lavrentiya
# Processing Record 13 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 10 | antipovka
# Processing Record 15 of Set 10 | mao
# Processing Record 16 of Set 10 | copiapo
# Processing Record 17 of Set 10 | dolores
# Processing Record 18 of Set 10 | baie-comeau
# Processing Record 19 of Set 10 | williams lake
# Processing Record 20 of Set 10 | sundargarh
# Processing Record 21 of Set 10 | vyartsilya
# Processing Record 22 of Set 10 | namibe
# Processing Record 23 of Set 10 | weligama
# Processing Record 24 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 10 | excelsior springs
# Processing Record 27 of Set 10 | acheng
# Processing Record 28 of Set 10 | voskresenskoye
# Processing Record 29 of Set 10 | kushiro
# Processing Record 30 of Set 10 | rudsar
# Processing Record 31 of Set 10 | rio claro
# Processing Record 32 of Set 10 | kodinsk
# Processing Record 33 of Set 10 | kapuskasing
# Processing Record 34 of Set 10 | yerbogachen
# Processing Record 35 of Set 10 | marawi
# Processing Record 36 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 10 | diffa
# Processing Record 38 of Set 10 | tuy hoa
# Processing Record 39 of Set 10 | klyuchi
# Processing Record 40 of Set 10 | barabai
# Processing Record 41 of Set 10 | novo aripuana
# Processing Record 42 of Set 10 | pelym
# Processing Record 43 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 10 | kulhudhuffushi
# Processing Record 45 of Set 10 | jabinyanah
# Processing Record 46 of Set 10 | polyarnyye zori
# Processing Record 47 of Set 10 | elko
# Processing Record 48 of Set 10 | banda aceh
# Processing Record 49 of Set 10 | guanica
# Processing Record 50 of Set 10 | nelson bay
# Processing Record 1 of Set 11 | solnechnyy
# Processing Record 2 of Set 11 | te anau
# Processing Record 3 of Set 11 | avera
# Processing Record 4 of Set 11 | bernalillo
# Processing Record 5 of Set 11 | bathsheba
# Processing Record 6 of Set 11 | malayal
# Processing Record 7 of Set 11 | nome
# Processing Record 8 of Set 11 | mizdah
# Processing Record 9 of Set 11 | belomorsk
# Processing Record 10 of Set 11 | nantucket
# Processing Record 11 of Set 11 | salalah
# Processing Record 12 of Set 11 | moree
# Processing Record 13 of Set 11 | cayenne
# Processing Record 14 of Set 11 | vaitape
# Processing Record 15 of Set 11 | quirinopolis
# Processing Record 16 of Set 11 | makakilo city
# Processing Record 17 of Set 11 | afogados da ingazeira
# Processing Record 18 of Set 11 | nokaneng
# Processing Record 19 of Set 11 | boueni
# Processing Record 20 of Set 11 | fort frances
# Processing Record 21 of Set 11 | hobyo
# Processing Record 22 of Set 11 | krasnoselkup
# Processing Record 23 of Set 11 | bilibino
# Processing Record 24 of Set 11 | mega
# Processing Record 25 of Set 11 | zaykovo
# Processing Record 26 of Set 11 | qaqortoq
# Processing Record 27 of Set 11 | rincon
# Processing Record 28 of Set 11 | oriximina
# Processing Record 29 of Set 11 | partizansk
# Processing Record 30 of Set 11 | brus laguna
# Processing Record 31 of Set 11 | lasa
# Processing Record 32 of Set 11 | waingapu
# Processing Record 33 of Set 11 | ambon
# Processing Record 34 of Set 11 | bukan
# Processing Record 35 of Set 11 | atambua
# Processing Record 36 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 11 | kavaratti
# Processing Record 38 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 11 | kamalia
# Processing Record 40 of Set 11 | grand-santi
# Processing Record 41 of Set 11 | chitipa
# Processing Record 42 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 11 | diego de almagro
# Processing Record 44 of Set 11 | general pico
# Processing Record 45 of Set 11 | yeniseysk
# Processing Record 46 of Set 11 | bhuban
# Processing Record 47 of Set 11 | pathein
# Processing Record 48 of Set 11 | katsuura
# Processing Record 49 of Set 11 | luang prabang
# Processing Record 50 of Set 11 | praya
# Processing Record 1 of Set 12 | kailua
# Processing Record 2 of Set 12 | lodja
# Processing Record 3 of Set 12 | mamaku
# Processing Record 4 of Set 12 | burnie
# Processing Record 5 of Set 12 | hovd
# Processing Record 6 of Set 12 | knysna
# Processing Record 7 of Set 12 | viedma
# Processing Record 8 of Set 12 | zyryanovsk
# Processing Record 9 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 12 | north myrtle beach
# Processing Record 11 of Set 12 | tazmalt
# Processing Record 12 of Set 12 | sesori
# Processing Record 13 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 12 | saint-pierre
# Processing Record 15 of Set 12 | honningsvag
# Processing Record 16 of Set 12 | goderich
# Processing Record 17 of Set 12 | warrnambool
# Processing Record 18 of Set 12 | axim
# Processing Record 19 of Set 12 | boddam
# Processing Record 20 of Set 12 | north bend
# Processing Record 21 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 12 | humaita
# Processing Record 23 of Set 12 | dogondoutchi
# Processing Record 24 of Set 12 | lodeynoye pole
# Processing Record 25 of Set 12 | pedernales
# Processing Record 26 of Set 12 | andros town
# Processing Record 27 of Set 12 | hermon
# Processing Record 28 of Set 12 | manakara
# Processing Record 29 of Set 12 | koshurnikovo
# Processing Record 30 of Set 12 | ushumun
# Processing Record 31 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 32 of Set 12 | vanimo
# Processing Record 33 of Set 12 | baghdad
# Processing Record 34 of Set 12 | dauphin
# Processing Record 35 of Set 12 | taltal
# Processing Record 36 of Set 12 | sweetwater
# Processing Record 37 of Set 12 | rudnogorsk
# Processing Record 38 of Set 12 | bosanska krupa
# Processing Record 39 of Set 12 | ipanema
# Processing Record 40 of Set 12 | afonso bezerra
# Processing Record 41 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 12 | america dourada
# Processing Record 43 of Set 12 | oxford
# Processing Record 44 of Set 12 | meulaboh
# Processing Record 45 of Set 12 | santa rosa del sur
# Processing Record 46 of Set 12 | cam ranh
# Processing Record 47 of Set 12 | tobermory
# Processing Record 48 of Set 12 | yatou
# Processing Record 49 of Set 12 | jimenez
# Processing Record 50 of Set 12 | miri
# Processing Record 1 of Set 13 | valle de allende
# Processing Record 2 of Set 13 | san juan tecuaco
# Processing Record 3 of Set 13 | gribanovskiy
# Processing Record 4 of Set 13 | atikokan
# Processing Record 5 of Set 13 | lamu
# Processing Record 6 of Set 13 | orgita
# Processing Record 7 of Set 13 | jacksonville
# Processing Record 8 of Set 13 | nuuk
# Processing Record 9 of Set 13 | eureka
# Processing Record 10 of Set 13 | maumere
# Processing Record 11 of Set 13 | constitucion
# Processing Record 12 of Set 13 | sri aman
# Processing Record 13 of Set 13 | churapcha
# Processing Record 14 of Set 13 | richards bay
# Processing Record 15 of Set 13 | khasan
# Processing Record 16 of Set 13 | vila
# Processing Record 17 of Set 13 | ankazoabo
# Processing Record 18 of Set 13 | horta
# Processing Record 19 of Set 13 | coahuayana
# Processing Record 20 of Set 13 | balikpapan
# Processing Record 21 of Set 13 | mae hong son
# Processing Record 22 of Set 13 | antalaha
# Processing Record 23 of Set 13 | maragogi
# Processing Record 24 of Set 13 | dirba
# Processing Record 25 of Set 13 | shingu
# Processing Record 26 of Set 13 | olinda
# Processing Record 27 of Set 13 | wilmington
# Processing Record 28 of Set 13 | alice springs
# Processing Record 29 of Set 13 | kayerkan
# Processing Record 30 of Set 13 | san rafael del sur
# Processing Record 31 of Set 13 | dawson creek
# Processing Record 32 of Set 13 | olafsvik
# Processing Record 33 of Set 13 | turbat
# Processing Record 34 of Set 13 | bichura
# Processing Record 35 of Set 13 | tahoua
# Processing Record 36 of Set 13 | gamba
# Processing Record 37 of Set 13 | katherine
# Processing Record 38 of Set 13 | cave spring
# Processing Record 39 of Set 13 | etchojoa
# Processing Record 40 of Set 13 | dhamtari
# Processing Record 41 of Set 13 | jiehu
# Processing Record 42 of Set 13 | oranjestad
# Processing Record 43 of Set 13 | nandyal
# Processing Record 44 of Set 13 | sistranda
# Processing Record 45 of Set 13 | muravlenko
# Processing Record 46 of Set 13 | la victoria
# Processing Record 47 of Set 13 | moroni
# Processing Record 48 of Set 13 | ust-maya
# Processing Record 49 of Set 13 | abu samrah
# Processing Record 50 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 1 of Set 14 | raga
# Processing Record 2 of Set 14 | aneza
# Processing Record 3 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 14 | houma
# Processing Record 5 of Set 14 | marzuq
# Processing Record 6 of Set 14 | balkhash
# Processing Record 7 of Set 14 | niigata
# Processing Record 8 of Set 14 | plastun
# Processing Record 9 of Set 14 | northam
# Processing Record 10 of Set 14 | sinegorskiy
# Processing Record 11 of Set 14 | terrace
# Processing Record 12 of Set 14 | la ferte-bernard
# Processing Record 13 of Set 14 | mwanza
# Processing Record 14 of Set 14 | ucluelet
# Processing Record 15 of Set 14 | aswan
# Processing Record 16 of Set 14 | verkhnevilyuysk
# Processing Record 17 of Set 14 | udachnyy
# Processing Record 18 of Set 14 | puerto madryn
# Processing Record 19 of Set 14 | datong
# Processing Record 20 of Set 14 | yazd
# Processing Record 21 of Set 14 | ustka
# Processing Record 22 of Set 14 | acarau
# Processing Record 23 of Set 14 | sydney
# Processing Record 24 of Set 14 | unguia
# Processing Record 25 of Set 14 | orcopampa
# Processing Record 26 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 27 of Set 14 | el carmen
# Processing Record 28 of Set 14 | san alberto
# Processing Record 29 of Set 14 | raudeberg
# Processing Record 30 of Set 14 | flin flon
# Processing Record 31 of Set 14 | pando
# Processing Record 32 of Set 14 | daru
# Processing Record 33 of Set 14 | arandis
# Processing Record 34 of Set 14 | molnlycke
# Processing Record 35 of Set 14 | gizo
# Processing Record 36 of Set 14 | magaria
# Processing Record 37 of Set 14 | pringsewu
# Processing Record 38 of Set 14 | norsup
# Processing Record 39 of Set 14 | lhokseumawe
# Processing Record 40 of Set 14 | ifo
# Processing Record 41 of Set 14 | antsohihy
# Processing Record 42 of Set 14 | jaru
# Processing Record 43 of Set 14 | pimentel
# Processing Record 44 of Set 14 | taloqan
# Processing Record 45 of Set 14 | fox lake
# Processing Record 46 of Set 14 | yining
# Processing Record 47 of Set 14 | rocha
# Processing Record 48 of Set 14 | saint-ambroise
# Processing Record 49 of Set 14 | bani walid
# Processing Record 50 of Set 14 | ararat
# Processing Record 1 of Set 15 | san juan
# Processing Record 2 of Set 15 | bandarbeyla
# Processing Record 3 of Set 15 | porosozero
# Processing Record 4 of Set 15 | jiayuguan
# Processing Record 5 of Set 15 | camalu
# Processing Record 6 of Set 15 | cruzeiro do sul
# Processing Record 7 of Set 15 | zalantun
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | acari
# Processing Record 10 of Set 15 | sorland
# Processing Record 11 of Set 15 | yairipok
# Processing Record 12 of Set 15 | sungaipenuh
# Processing Record 13 of Set 15 | dakar
# Processing Record 14 of Set 15 | soma
# Processing Record 15 of Set 15 | juneau
# Processing Record 16 of Set 15 | matara
# Processing Record 17 of Set 15 | acambay
# Processing Record 18 of Set 15 | fairbanks
# Processing Record 19 of Set 15 | bac can
# City not found. Skipping...
# Processing Record 20 of Set 15 | mehamn
# Processing Record 21 of Set 15 | manzhouli
# Processing Record 22 of Set 15 | great bend
# Processing Record 23 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 15 | mozarlandia
# Processing Record 25 of Set 15 | timmins
# Processing Record 26 of Set 15 | diveyevo
# Processing Record 27 of Set 15 | talnakh
# Processing Record 28 of Set 15 | guadalupe victoria
# Processing Record 29 of Set 15 | manokwari
# Processing Record 30 of Set 15 | vila do maio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 673

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        La Ronge  55.1001 -105.2842     21.45          light snow        73
# 1      Hammerfest  70.6634   23.6821     37.85       broken clouds        75
# 2    Kruisfontein -34.0033   24.7314     66.88     overcast clouds        80
# 3           Vaini -21.2000 -175.2000     78.96       broken clouds        83
# 4       Lancaster  40.2504  -76.2499     45.63          few clouds        52
# 5          Castro -24.7911  -50.0119     68.85     overcast clouds        81
# 6       Tilichiki  60.4667  166.1000     12.20     overcast clouds        97
# 7       Ugoofaaru   5.6667   73.0000     80.96     overcast clouds        78
# 8       Busselton -33.6500  115.3333     50.90           clear sky        83
# 9  Cabo San Lucas  22.8909 -109.9124     82.18          few clouds        66
#
#    Cloudiness  Wind Speed Country
# 0         100        3.44      CA
# 1          75        6.91      NO
# 2          90        8.72      ZA
# 3          75        6.91      TO
# 4          20        8.05      US
# 5          97        6.04      BR
# 6         100       10.83      RU
# 7         100       10.98      MV
# 8           0       10.54      AU
# 9          18        9.26      MX

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
city_data_df["Lat"] = city_data_df["Lat"].round(2)
city_data_df["Lng"] = city_data_df["Lng"].round(2)

# Display sample data
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        La Ronge      CA  55.10 -105.28     21.45        73         100
# 1      Hammerfest      NO  70.66   23.68     37.85        75          75
# 2    Kruisfontein      ZA -34.00   24.73     66.88        80          90
# 3           Vaini      TO -21.20 -175.20     78.96        83          75
# 4       Lancaster      US  40.25  -76.25     45.63        52          20
# 5          Castro      BR -24.79  -50.01     68.85        81          97
# 6       Tilichiki      RU  60.47  166.10     12.20        97         100
# 7       Ugoofaaru      MV   5.67   73.00     80.96        78         100
# 8       Busselton      AU -33.65  115.33     50.90        83           0
# 9  Cabo San Lucas      MX  22.89 -109.91     82.18        66          18
#
#    Wind Speed Current Description
# 0        3.44          light snow
# 1        6.91       broken clouds
# 2        8.72     overcast clouds
# 3        6.91       broken clouds
# 4        8.05          few clouds
# 5        6.04     overcast clouds
# 6       10.83     overcast clouds
# 7       10.98     overcast clouds
# 8       10.54           clear sky
# 9        9.26          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPY_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
